# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline

# %%
@widgets.interact
def f(x=5):
    print(x)
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=15, min=-5), Output()), _dom_classes=('widget-in…

# %%
@widgets.interact_manual(
    color=['blue', 'red', 'green'], lw=(1., 10.))
def plot(freq=1., color='blue', lw=2, grid=True):
    t = np.linspace(-1., +1., 1000)
    fig, ax = plt.subplots(1, 1, figsize=(8, 6))
    ax.plot(t, np.sin(2 * np.pi * freq * t),
            lw=lw, color=color)
    ax.grid(grid)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='freq', max=3.0, min=-1.0), Dropdown(description='col…

# %%
import altair as alt
from vega_datasets import data

# %%
source
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 0         130.0           3504          12.0 1970-01-01     USA
# 1         165.0           3693          11.5 1970-01-01     USA
# 2         150.0           3436          11.0 1970-01-01     USA
# 3         150.0           3433          12.0 1970-01-01     USA
# 4         140.0           3449          10.5 1970-01-01     USA
# ..          ...            ...           ...        ...     ...
# 401        86.0           2790          15.6 1982-01-01     USA
# 402        52.0           2130          24.6 1982-01-01  Europe
# 403        84.0           2295          11.6 1982-01-01     USA
# 404        79.0           2625          18.6 1982-01-01     USA
# 405        82.0           2720          19.4 1982-01-01     USA
#
# [406 rows x 9 columns]

# %%
source = data.cars()

# %%
from ipywidgets import interact

# %%
def altair_plot(origin):
    origin_list = origin if isinstance(origin, list) else [origin]
    df = source.loc[lambda x: x["Origin"].isin(origin_list)]
    chart = alt.Chart(df).mark_circle(size=60).encode(
        x='Horsepower',
        y='Miles_per_Gallon',
        color='Origin',
        tooltip=['Name', 'Origin', 'Horsepower', 'Miles_per_Gallon']
    ).interactive()
    return chart

interact(altair_plot, origin = sorted(source['Origin'].unique()), );
# Out:
# interactive(children=(Dropdown(description='origin', options=('Europe', 'Japan', 'USA'), value='Europe'), Outp…

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 2 * np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1.0):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw_idle()

interact(update);
# Out:
# <div id='cedbc7c5-94ce-4563-87f4-113b5a1fe4fd'></div>
# interactive(children=(FloatSlider(value=1.0, description='w', max=3.0, min=-1.0), Output()), _dom_classes=('wi…
# <div id='aa55745a-0803-4367-9e0d-e53bccabe93c'></div>

# %%
# !jupyterlab
# Out:
# /bin/sh: 1: jupyterlab: not found

# %%
def plot_func(freq):
    x = np.linspace(0, 2*np.pi,1000)
    y = np.sin(x * freq)
    plt.plot(x, y)
    plt.show()

interact(plot_func, freq = widgets.FloatSlider(value=2.5, min=1, 
max=5.0,step=0.5))
# Out:
# interactive(children=(FloatSlider(value=2.5, description='freq', max=5.0, min=1.0, step=0.5), Output()), _dom_…
# <function __main__.plot_func(freq)>

# %% [markdown]
# Before we start, we import some preliminary libraries. We will also import (below) the accompanying `lorenz.py` file, which contains the actual solver and plotting routine.

# %%
# %matplotlib inline
from ipywidgets import interactive, fixed

# %% [markdown]
# We explore the Lorenz system of differential equations:
#
# $$
# \begin{aligned}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{aligned}
# $$
#
# Let's change (\\(\sigma\\), \\(\beta\\), \\(\rho\\)) with ipywidgets and examine the trajectories.

# %%
from lorenz import solve_lorenz
w=interactive(solve_lorenz,sigma=(0.0,50.0),rho=(0.0,50.0))
w

# %% [markdown]
# For the default set of parameters, we see the trajectories swirling around two points, called attractors.
# The object returned by `interactive` is a `Widget` object and it has attributes that contain the current result and arguments:

# %%
t, x_t = w.result

# %%
w.kwargs

# %%
After interacting with the system, we can take the result and perform further computations. In this case, we compute the average positions in \\(x\\), \\(y\\) and \\(z\\).
